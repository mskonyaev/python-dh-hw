# %%
# Задача 1 
penguin1 = '   _~_   '
penguin2 = '  (o o)  '
penguin3 = ' /  V  \\ '
penguin4 = '/(  _  )\\'
penguin5 = '  ^^ ^^  '
n = input('Введите количество пингвинов: ')
print(penguin1*n)
print(penguin2*n)
print(penguin3*n)
print(penguin4*n)
print(penguin5*n)
# Out:
# Введите количество пингвинов: 6
#    _~_      _~_      _~_      _~_      _~_      _~_
#   (o o)    (o o)    (o o)    (o o)    (o o)    (o o)
#  /  V  \  /  V  \  /  V  \  /  V  \  /  V  \  /  V  \
# /(  _  )\/(  _  )\/(  _  )\/(  _  )\/(  _  )\/(  _  )\
#   ^^ ^^    ^^ ^^    ^^ ^^    ^^ ^^    ^^ ^^    ^^ ^^

# %%
# Задача 2
stroka = input('Введите строку: ')
words = stroka.split()
letters = list(stroka)
c = 0
l = 0
for t in words:
    c += 1
for t in letters:
    l += 1
print('Количество слов: %d \nКоличество символов: %d' % (c, l))
# Out:
# Введите строку: hello people
# Количество слов: 2
# Количество символов: 12

# %%
# Задача 3
s = "Между идеей и повседневностью падает тень"
#1 - третий символ строки
print(s[2])
#2 - предпоследний символ строки
print(s[-2])
#3 - первые пять символов символов строки
print(s[:5])
#4 -вся строка, кроме последних двух символов
print(s[:-2])
#5 - все символы с четными индексами
print(s[::2])
#6 - все символы с нечетными индексами
print(s[1::2])
#7 - все символы в обратном порядке
print(s[::-1])
#8 - все символы символы через один в обратном порядке, начиная с последнего
print(s[::-2])
#9 - длина данной строки
print(len(s))
# Out:
# ж
# н
# Между
# Между идеей и повседневностью падает те
# Мжуиейипвенвотюпде еь
# ед де  осденсь ааттн
# ьнет теадап юьтсонвендесвоп и йееди уджеМ
# ье едпютовневпийеиужМ
# 41

# %%
# Задача 4 - ответ YES 
# str.lower() использована для того, чтобы игнорировать большие буквы в инпуте
slovo1 = str.lower(input('Введите слово: '))
slovo2 = slovo1[::-1]
if slovo1 == slovo2:
    print('YES')
else:
    print('NO')

# Задание 4 - ответ NO
slovo1 = str.lower(input('Введите слово: '))
slovo2 = slovo1[::-1]
if slovo1 == slovo2:
    print('YES')
else:
    print('NO')
# Out:
# Введите слово: потоп
# YES
# Введите слово: котенок
# NO

# %%
# Задача 5
text = '''законы физики рядом с черной дырой уже не работают в том представлении в котором мы привыкли 
пространство время искривляется и все события протекают уже совсем по другому 
словно пылесос черная дыра поглощает все что находится около нее планеты астероиды свет и прочее 
ранее считалось что черная дыра ничего не излучает но как доказал стивен хокинг черная дыра излучает антивещество 
то есть поедает вещество и выделяет антивещество 
ранее думали что если кинуть в черную дыру человека то ему труба порвет на субатомы 
но как оказалось по некоторым уравнениям есть определенные траектории путешествия сквозь черную дыру чтоб чувствовать себя нормально 
правда не ясно что будет за ней другой мир или ничего 
область вокруг черной дыры которая интересна называется горизонтом событий 
если туда полететь не зная волшебное уравнение то будет конечно не очень 
наблюдатель будет видеть как космический корабль влетает в горизонт событий и крайне медленно потом отдаляется пока не застынет в центре
у самого же космонавта дела будут идти совсем по другому 
искривленное пространство будет лепить из него как из пластилина различные формы пока наконец не разорвет все на субатомы 
но для внешнего наблюдателя космонавт навсегда останется улыбающимся и махающим в иллюминатор застывшим изображением'''
slova = text.split()
c = 0
inp = input('Введите слово: ')
if inp in slova:
    for i in slova:
        if i == inp:
            c += 1
    print('Слово %s встречается в тексте %d раз' % (inp, c))
else:
    slova.append(inp)
    print('Слово добавлено!')
# Out:
# Введите слово: труба
# Слово труба встречается в тексте 1 раз
